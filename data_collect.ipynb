# %%
import pandas as pd

# %%
data1 = pd.read_csv('C:\\VS code\\FLEXI\\Projecty\\startup data.csv')
data2 = pd.read_csv('C:\\VS code\\FLEXI\\Projecty\\big_startup_secsees_dataset.csv')

# %%
data1.head()
# Out:
#    Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0        1005         CA  42.358880  -71.056820    92101   c:6669
# 1         204         CA  37.238916 -121.973718    95032  c:16283
# 2        1001         CA  32.901049 -117.192656    92121  c:65620
# 3         738         CA  37.320309 -122.050040    95014  c:42668
# 4        1002         CA  37.779281 -122.419236    94105  c:65806
#
#             city              Unnamed: 6               name  labels  ...  \
# 0      San Diego                     NaN        Bandsintown       1  ...
# 1      Los Gatos                     NaN          TriCipher       1  ...
# 2      San Diego      San Diego CA 92121              Plixi       1  ...
# 3      Cupertino      Cupertino CA 95014  Solidcore Systems       1  ...
# 4  San Francisco  San Francisco CA 94105     Inhale Digital       0  ...
#
#   object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# 0    c:6669      0         1          0           0           0           0
# 1   c:16283      1         0          0           1           1           1
# 2   c:65620      0         0          1           0           0           0
# 3   c:42668      0         0          0           1           1           1
# 4   c:65806      1         1          0           0           0           0
#
#    avg_participants  is_top500    status
# 0            1.0000          0  acquired
# 1            4.7500          1  acquired
# 2            4.0000          1  acquired
# 3            3.3333          1  acquired
# 4            1.0000          1    closed
#
# [5 rows x 49 columns]

# %%
data2.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                923 non-null    int64
#  1   state_code                923 non-null    object
#  2   latitude                  923 non-null    float64
#  3   longitude                 923 non-null    float64
#  4   zip_code                  923 non-null    object
#  5   id                        923 non-null    object
#  6   city                      923 non-null    object
#  7   Unnamed: 6                430 non-null    object
#  8   name                      923 non-null    object
#  9   labels                    923 non-null    int64
#  10  founded_at                923 non-null    object
#  11  closed_at                 335 non-null    object
#  12  first_funding_at          923 non-null    object
#  13  last_funding_at           923 non-null    object
#  14  age_first_funding_year    923 non-null    float64
#  15  age_last_funding_year     923 non-null    float64
#  16  age_first_milestone_year  771 non-null    float64
#  17  age_last_milestone_year   771 non-null    float64
#  18  relationships             923 non-null    int64
#  19  funding_rounds            923 non-null    int64
#  20  funding_total_usd         923 non-null    int64
#  21  milestones                923 non-null    int64
#  22  state_code.1              922 non-null    object
#  23  is_CA                     923 non-null    int64
#  24  is_NY                     923 non-null    int64
#  25  is_MA                     923 non-null    int64
#  26  is_TX                     923 non-null    int64
#  27  is_otherstate             923 non-null    int64
#  28  category_code             923 non-null    object
#  29  is_software               923 non-null    int64
#  30  is_web                    923 non-null    int64
#  31  is_mobile                 923 non-null    int64
#  32  is_enterprise             923 non-null    int64
#  33  is_advertising            923 non-null    int64
#  34  is_gamesvideo             923 non-null    int64
#  35  is_ecommerce              923 non-null    int64
#  36  is_biotech                923 non-null    int64
#  37  is_consulting             923 non-null    int64
#  38  is_othercategory          923 non-null    int64
#  39  object_id                 923 non-null    object
#  40  has_VC                    923 non-null    int64
#  41  has_angel                 923 non-null    int64
#  42  has_roundA                923 non-null    int64
#  43  has_roundB                923 non-null    int64
#  44  has_roundC                923 non-null    int64
#  45  has_roundD                923 non-null    int64
#  46  avg_participants          923 non-null    float64
#  47  is_top500                 923 non-null    int64
#  48  status                    923 non-null    object
# dtypes: float64(7), int64(28), object(14)
# memory usage: 353.5+ KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   permalink          66368 non-null  object
#  1   name               66367 non-null  object
#  2   homepage_url       61310 non-null  object
#  3   category_list      63220 non-null  object
#  4   funding_total_usd  66368 non-null  object
#  5   status             66368 non-null  object
#  6   country_code       59410 non-null  object
#  7   state_code         57821 non-null  object
#  8   region             58338 non-null  object
#  9   city               58340 non-null  object
#  10  funding_rounds     66368 non-null  int64
#  11  founded_at         51147 non-null  object
#  12  first_funding_at   66344 non-null  object
#  13  last_funding_at    66368 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %% [markdown]
# Selected Columns:
# name, category_list, funding_total_usd, state_code, country_code, funding_rounds, founded_at, first_funding_at, last_funding_at, status

# %%
data2['status'].value_counts()
# Out:
# status
# operating    53034
# closed        6238
# acquired      5549
# ipo           1547
# Name: count, dtype: int64

# %%
DF = data2[['name', 'category_list', 'funding_total_usd', 'country_code', 'state_code', 'founded_at', 'funding_rounds', 'first_funding_at', 'last_funding_at', 'status']].copy()

# %%
DF.head()
# Out:
#                      name                                      category_list  \
# 0                   #fame                                              Media
# 1                :Qounter  Application Platforms|Real Time|Social Network...
# 2  (THE) ONE of THEM,Inc.                                  Apps|Games|Mobile
# 3                 0-6.com                                        Curated Web
# 4        004 Technologies                                           Software
#
#   funding_total_usd country_code state_code  founded_at  funding_rounds  \
# 0          10000000          IND         16         NaN               1
# 1            700000          USA         DE  2014-09-04               2
# 2           3406878          NaN        NaN         NaN               1
# 3           2000000          CHN         22  2007-01-01               1
# 4                 -          USA         IL  2010-01-01               1
#
#   first_funding_at last_funding_at     status
# 0       2015-01-05      2015-01-05  operating
# 1       2014-03-01      2014-10-14  operating
# 2       2014-01-30      2014-01-30  operating
# 3       2008-03-19      2008-03-19  operating
# 4       2014-07-24      2014-07-24  operating

# %%
DF_operating = DF[DF['status'] == 'operating'].copy()

# %%
DF = DF[DF['status'] != 'operating'].copy()

# %%
DF.head()
# Out:
#             name                     category_list funding_total_usd  \
# 15  1 Mainstream  Apps|Cable|Distribution|Software           5000000
# 20  1000 Markets       Art|E-Commerce|Marketplaces            500000
# 23  1000memories                       Curated Web           2535000
# 31       100Plus                         Analytics           1250000
# 32      1010data                          Software          35000000
#
#    country_code state_code  founded_at  funding_rounds first_funding_at  \
# 15          USA         CA  2012-03-01               1       2015-03-17
# 20          USA         WA  2009-01-01               1       2009-05-15
# 23          USA         CA  2010-07-01               2       2010-01-01
# 31          USA         CA  2011-09-16               2       2011-11-02
# 32          USA         NY  2000-01-01               1       2010-03-08
#
#    last_funding_at    status
# 15      2015-03-17  acquired
# 20      2009-05-15  acquired
# 23      2011-02-16  acquired
# 31      2011-11-30  acquired
# 32      2010-03-08  acquired

# %%
DF['status'].value_counts()
# Out:
# status
# closed      6238
# acquired    5549
# ipo         1547
# Name: count, dtype: int64

# %%
DF_operating['status'].value_counts()
# Out:
# status
# operating    53034
# Name: count, dtype: int64

# %%
DF_operating.to_csv('C:\\VS code\\FLEXI\\Projecty\\operating_startup.csv', index=False)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13334 entries, 15 to 66360
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13333 non-null  object
#  1   category_list      12248 non-null  object
#  2   funding_total_usd  13334 non-null  object
#  3   country_code       11343 non-null  object
#  4   state_code         11125 non-null  object
#  5   founded_at         9602 non-null   object
#  6   funding_rounds     13334 non-null  int64
#  7   first_funding_at   13332 non-null  object
#  8   last_funding_at    13334 non-null  object
#  9   status             13334 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ MB

# %%
DF['category_list'].value_counts()
# Out:
# category_list
# Software                                                                            917
# Biotechnology                                                                       807
# Curated Web                                                                         373
# Mobile                                                                              272
# Enterprise Software                                                                 247
#                                                                                    ...
# Mobile|SMS                                                                            1
# Design|Hardware + Software|Health and Wellness                                        1
# Automotive|Data Security|Education|Kids|Portals|Public Relations                      1
# Cloud Computing|Enterprise 2.0|Enterprise Software|MicroBlogging|Social Business      1
# Apps|Cable|Distribution|Software                                                      1
# Name: count, Length: 5747, dtype: int64

# %%
# Split category_list by '|', flatten the list, and get unique values
unique_categories = set(DF['category_list'].dropna().str.split('|').sum())

# Count the number of unique categories
num_unique_categories = len(unique_categories)

print(f"Total unique categories: {num_unique_categories}")
print(unique_categories)  # Display all unique category names
# Out:
# Total unique categories: 737
# {'Entertainment', 'Medical Professionals', 'Charter Schools', '3D Technology', 'Internet TV', 'Advertising', 'Bitcoin', 'Oil', 'Semiconductors', 'Personal Branding', 'Veterinary', 'Mobile Commerce', 'Public Transportation', 'Event Management', 'Sustainability', 'Elder Care', 'Home Renovation', 'Wind', 'Wholesale', 'Tracking', 'Golf Equipment', 'Home Owners', 'Price Comparison', 'Finance Technology', 'Gift Exchange', 'Email Marketing', '3D', 'Visual Search', 'Social Entrepreneurship', 'Real Estate', 'Clinical Trials', 'Network Security', 'Cooking', 'Lighting', 'Enterprises', 'Cloud Security', 'Social Media Monitoring', 'Broadcasting', 'Enterprise Security', 'Virtual Workforces', 'Business Travelers', 'Lifestyle', 'Gadget', 'Apps', 'High Tech', 'Private Social Networking', 'Travel', 'Social Games', 'Legal', 'Group Buying', 'Fraud Detection', 'Cyber', 'Renewable Energies', 'Portals', 'Artificial Intelligence', 'Business Intelligence', 'E-Commerce Platforms', 'Investment Management', 'DIY', 'Business Services', 'Cars', 'Market Research', 'Public Safety', 'Non Profit', 'Peer-to-Peer', 'Internet of Things', 'Mechanical Solutions', 'Shared Services', 'Web CMS', 'Remediation', 'Nightlife', 'Sales Automation', 'Direct Marketing', 'Communications Infrastructure', 'Green Building', 'Freelancers', 'Transportation', 'Self Storage', 'Eyewear', 'Religion', 'Gamification', 'Mobile Emergency&Health', 'Active Lifestyle', 'B2B', 'Nanotechnology', 'MicroBlogging', 'Virtualization', 'Crowdsourcing', 'Specialty Chemicals', 'All Students', 'Sales and Marketing', 'Consumer Behavior', 'Marketing Automation', 'Visualization', 'Manufacturing', 'Advanced Materials', 'SMS', 'Shoes', 'Residential Solar', 'Mac', 'Cloud Management', 'Google Apps', 'Browser Extensions', 'Offline Businesses', 'Estimation and Quoting', 'Gold', 'SaaS', 'Motors', 'Fantasy Sports', 'Groceries', 'Loyalty Programs', 'Health and Insurance', 'Writers', 'Training', 'Social CRM', 'Waste Management', 'Venture Capital', 'Oil and Gas', 'Analytics', 'IT and Cybersecurity', 'Embedded Hardware and Software', 'iOS', 'Music', 'Digital Rights Management', 'Carbon', 'Logistics Company', 'Neuroscience', 'Intellectual Property', 'Simulation', 'Rehabilitation', 'Homeland Security', 'Nonprofits', 'Space Travel', 'Media', 'Medical Devices', 'Art', 'Shopping', 'Agriculture', 'Internet Infrastructure', 'Hardware', 'Personal Health', 'Forums', 'Engineering Firms', 'Senior Health', 'Resorts', 'Local Coupons', 'Trusted Networks', 'Cloud Infrastructure', 'MMO Games', 'Baby Accessories', 'Auto', 'Internet Service Providers', 'Franchises', 'Coffee', 'Mobile Social', 'Textiles', 'Finance', 'QR Codes', 'Gift Card', 'Baby Safety', 'Data Integration', 'Indians', 'Supply Chain Management', 'Private Corrections', 'Natural Language Processing', 'Developer APIs', 'Gift Registries', 'Wealth Management', 'Environmental Innovation', 'E-Commerce', 'Fashion', 'RFID', 'Business Information Systems', 'Families', 'Transaction Processing', 'Financial Exchanges', 'Mobile Devices', 'Aerospace', 'Tourism', 'Virtual Worlds', 'Credit', 'Wine And Spirits', 'Semantic Web', 'Intelligent Systems', 'Cannabis', 'Product Design', 'Music Services', 'Information Services', 'Banking', 'Nutrition', 'Bio-Pharm', 'In-Flight Entertainment', 'Guides', 'Wireless', 'Productivity Software', 'Classifieds', 'Machine Learning', 'Linux', 'Recreation', 'Postal and Courier Services', 'Water Purification', 'M2M', 'Customer Support Tools', 'Social Innovation', 'Multi-level Marketing', 'Hospitality', 'Startups', 'Mobile Games', 'Internet Radio Market', 'Cloud-Based Music', 'Hospitals', 'Celebrity', 'Comparison Shopping', 'Contact Centers', 'Semiconductor Manufacturing Equipment', 'Law Enforcement', 'Monetization', 'Hedge Funds', 'Physical Security', 'Printing', 'Teenagers', 'Content Creators', 'Commercial Real Estate', 'Freemium', 'Home & Garden', 'Concentrated Solar Power', 'Innovation Engineering', 'Blogging Platforms', 'Distributors', 'Enterprise Hardwar ...

# %%
# Filter rows where category_list does NOT contain '|'
df_single_category = DF[~DF['category_list'].str.contains('\|', na=False)]
category_counts = df_single_category['category_list'].value_counts()

# %%
categories_to_keep = category_counts[category_counts >= 20].index

# Filter the DataFrame to include only those categories
df_filtered = df_single_category[df_single_category['category_list'].isin(categories_to_keep)]

# %%
df_filtered['category_list'].value_counts()
# Out:
# category_list
# Software               917
# Biotechnology          807
# Curated Web            373
# Mobile                 272
# Enterprise Software    247
# Clean Technology       210
# E-Commerce             208
# Games                  197
# Semiconductors         196
# Advertising            194
# Hardware + Software    192
# Health Care            186
# Web Hosting            132
# Security               127
# Health and Wellness     86
# Social Media            80
# Finance                 79
# Manufacturing           76
# Analytics               67
# Public Relations        66
# Messaging               57
# Consulting              52
# Education               46
# Technology              43
# Music                   41
# News                    39
# Travel                  38
# Search                  35
# Real Estate             31
# Pharmaceuticals         30
# Fashion                 29
# Hospitality             28
# Photography             23
# Automotive              22
# Sports                  21
# Name: count, dtype: int64

# %%
category_cols = {
    "is_software": "Software",
    "is_web": "Web",
    "is_mobile": "Mobile",
    "is_enterprise": "Enterprise",
    "is_advertising": "Advertising",
    "is_gamesvideo": "Games",
    "is_ecommerce": "E-Commerce",
    "is_biotech": "Biotech",
    "is_consulting": "Consulting"
}

data1["category_list"] = data1.apply(lambda row: "|".join([name for col, name in category_cols.items() if row[col] == 1]), axis=1)

# %%
data1['category_list'].value_counts()
# Out:
# category_list
#                298
# Software       153
# Web            144
# Mobile          79
# Enterprise      73
# Advertising     62
# Games           52
# Biotech         34
# E-Commerce      25
# Consulting       3
# Name: count, dtype: int64

# %%
data1 = data1[data1['category_list'].str.strip() != ""]  # Just in case there are empty strings

print(data1['category_list'].value_counts())
# Out:
# category_list
# Software       153
# Web            144
# Mobile          79
# Enterprise      73
# Advertising     62
# Games           52
# Biotech         34
# E-Commerce      25
# Consulting       3
# Name: count, dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 625 entries, 1 to 921
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                625 non-null    int64
#  1   state_code                625 non-null    object
#  2   latitude                  625 non-null    float64
#  3   longitude                 625 non-null    float64
#  4   zip_code                  625 non-null    object
#  5   id                        625 non-null    object
#  6   city                      625 non-null    object
#  7   Unnamed: 6                270 non-null    object
#  8   name                      625 non-null    object
#  9   labels                    625 non-null    int64
#  10  founded_at                625 non-null    object
#  11  closed_at                 219 non-null    object
#  12  first_funding_at          625 non-null    object
#  13  last_funding_at           625 non-null    object
#  14  age_first_funding_year    625 non-null    float64
#  15  age_last_funding_year     625 non-null    float64
#  16  age_first_milestone_year  540 non-null    float64
#  17  age_last_milestone_year   540 non-null    float64
#  18  relationships             625 non-null    int64
#  19  funding_rounds            625 non-null    int64
#  20  funding_total_usd         625 non-null    int64
#  21  milestones                625 non-null    int64
#  22  state_code.1              625 non-null    object
#  23  is_CA                     625 non-null    int64
#  24  is_NY                     625 non-null    int64
#  25  is_MA                     625 non-null    int64
#  26  is_TX                     625 non-null    int64
#  27  is_otherstate             625 non-null    int64
#  28  category_code             625 non-null    object
#  29  is_software               625 non-null    int64
#  30  is_web                    625 non-null    int64
#  31  is_mobile                 625 non-null    int64
#  32  is_enterprise             625 non-null    int64
#  33  is_advertising            625 non-null    int64
#  34  is_gamesvideo             625 non-null    int64
#  35  is_ecommerce              625 non-null    int64
#  36  is_biotech                625 non-null    int64
#  37  is_consulting             625 non-null    int64
#  38  is_othercategory          625 non-null    int64
#  39  object_id                 625 non-null    object
#  40  has_VC                    625 non-null    int64
#  41  has_angel                 625 non-null    int64
#  42  has_roundA                625 non-null    int64
#  43  has_roundB                625 non-null    int64
#  44  has_roundC                625 non-null    int64
#  45  has_roundD                625 non-null    int64
#  46  avg_participants          625 non-null    float64
#  47  is_top500                 625 non-null    int64
#  48  status                    625 non-null    object
#  49  category_list             625 non-null    object
# dtypes: float64(7), int64(28), object(15)
# memory usage: 249.0+ KB

# %%
data1 = data1[['name', 'category_list', 'funding_total_usd', 'state_code.1', 'founded_at', 'funding_rounds', 'first_funding_at', 'last_funding_at', 'status']].copy()

# %%
data1.head()
# Out:
#                     name category_list  funding_total_usd state_code.1  \
# 1              TriCipher    Enterprise           40100000           CA
# 2                  Plixi           Web            2600000           CA
# 3      Solidcore Systems      Software           40000000           CA
# 4         Inhale Digital         Games            1300000           CA
# 6  RingCube Technologies      Software           26000000           CA
#
#   founded_at  funding_rounds first_funding_at last_funding_at    status
# 1   1/1/2000               4        2/14/2005      12/28/2009  acquired
# 2  3/18/2009               1        3/30/2010       3/30/2010  acquired
# 3   1/1/2002               3        2/17/2005       4/25/2007  acquired
# 4   8/1/2010               2         8/1/2010        4/1/2012    closed
# 6   1/1/2005               3        9/21/2006       3/18/2010  acquired

# %%
data1["state_code.1"].value_counts()
# Out:
# state_code.1
# CA    323
# NY     74
# MA     63
# WA     29
# TX     23
# IL     15
# PA     12
# VA     11
# CO     11
# GA      8
# FL      5
# MD      5
# NC      5
# OR      4
# OH      4
# NJ      4
# DC      3
# RI      3
# MN      3
# NH      2
# KY      2
# MI      2
# UT      2
# TN      2
# CT      2
# WV      1
# MO      1
# IN      1
# ME      1
# AZ      1
# ID      1
# AR      1
# WI      1
# Name: count, dtype: int64

# %% [markdown]
# All State codes are of country USA

# %%
data1['country_code'] = 'USA'

# %%
data1.head()
# Out:
#                     name category_list  funding_total_usd state_code.1  \
# 1              TriCipher    Enterprise           40100000           CA
# 2                  Plixi           Web            2600000           CA
# 3      Solidcore Systems      Software           40000000           CA
# 4         Inhale Digital         Games            1300000           CA
# 6  RingCube Technologies      Software           26000000           CA
#
#   founded_at  funding_rounds first_funding_at last_funding_at    status  \
# 1   1/1/2000               4        2/14/2005      12/28/2009  acquired
# 2  3/18/2009               1        3/30/2010       3/30/2010  acquired
# 3   1/1/2002               3        2/17/2005       4/25/2007  acquired
# 4   8/1/2010               2         8/1/2010        4/1/2012    closed
# 6   1/1/2005               3        9/21/2006       3/18/2010  acquired
#
#   country_code
# 1          USA
# 2          USA
# 3          USA
# 4          USA
# 6          USA

# %%
data1 = data1.rename(columns={'state_code.1': 'state_code'})

# %%
data1.head()
# Out:
#                     name category_list  funding_total_usd state_code  \
# 1              TriCipher    Enterprise           40100000         CA
# 2                  Plixi           Web            2600000         CA
# 3      Solidcore Systems      Software           40000000         CA
# 4         Inhale Digital         Games            1300000         CA
# 6  RingCube Technologies      Software           26000000         CA
#
#   founded_at  funding_rounds first_funding_at last_funding_at    status  \
# 1   1/1/2000               4        2/14/2005      12/28/2009  acquired
# 2  3/18/2009               1        3/30/2010       3/30/2010  acquired
# 3   1/1/2002               3        2/17/2005       4/25/2007  acquired
# 4   8/1/2010               2         8/1/2010        4/1/2012    closed
# 6   1/1/2005               3        9/21/2006       3/18/2010  acquired
#
#   country_code
# 1          USA
# 2          USA
# 3          USA
# 4          USA
# 6          USA

# %%
df_combined = pd.concat([df_filtered, data1], ignore_index=True)

# %%
df_combined.head()
# Out:
#             name        category_list funding_total_usd country_code  \
# 0   1000memories          Curated Web           2535000          USA
# 1        100Plus            Analytics           1250000          USA
# 2       1010data             Software          35000000          USA
# 3   10BestThings          Curated Web             50000          USA
# 4  11i Solutions  Enterprise Software           1800000          USA
#
#   state_code  founded_at  funding_rounds first_funding_at last_funding_at  \
# 0         CA  2010-07-01               2       2010-01-01      2011-02-16
# 1         CA  2011-09-16               2       2011-11-02      2011-11-30
# 2         NY  2000-01-01               1       2010-03-08      2010-03-08
# 3         OH  2009-04-01               1       2009-04-01      2009-04-01
# 4         AL         NaN               1       2011-03-22      2011-03-22
#
#      status
# 0  acquired
# 1  acquired
# 2  acquired
# 3    closed
# 4    closed

# %%
df_combined.shape
# Out:
# (5872, 10)

# %%
df_combined['country_code'].value_counts()
# Out:
# country_code
# USA    4358
# GBR     240
# CAN     202
# ISR      91
# DEU      81
# CHN      75
# FRA      75
# IND      50
# RUS      43
# SWE      40
# AUS      30
# ESP      23
# CHE      19
# JPN      19
# SGP      18
# NLD      18
# IRL      16
# BEL      15
# DNK      15
# ITA      14
# BRA      13
# NOR      13
# FIN      12
# ARG       9
# HKG       9
# KOR       9
# NZL       8
# AUT       6
# TUR       5
# MYS       4
# ARE       4
# CHL       4
# ZAF       3
# TWN       3
# CZE       3
# JOR       2
# BGR       2
# GRC       2
# HUN       2
# UKR       2
# BMU       2
# PRT       2
# NGA       2
# THA       2
# POL       2
# LVA       1
# KEN       1
# PRI       1
# ISL       1
# LUX       1
# MEX       1
# PER       1
# BLR       1
# MAF       1
# PAK       1
# Name: count, dtype: int64

# %%
df_combined['status'].value_counts()
# Out:
# status
# acquired    2904
# closed      2244
# ipo          724
# Name: count, dtype: int64

# %%
df_combined.to_csv('C:\\VS code\\FLEXI\\Projecty\\final_startup_dataset.csv', index=False)

# %%
DF.head()
# Out:
#             name                     category_list funding_total_usd  \
# 15  1 Mainstream  Apps|Cable|Distribution|Software           5000000
# 20  1000 Markets       Art|E-Commerce|Marketplaces            500000
# 23  1000memories                       Curated Web           2535000
# 31       100Plus                         Analytics           1250000
# 32      1010data                          Software          35000000
#
#    country_code state_code  founded_at  funding_rounds first_funding_at  \
# 15          USA         CA  2012-03-01               1       2015-03-17
# 20          USA         WA  2009-01-01               1       2009-05-15
# 23          USA         CA  2010-07-01               2       2010-01-01
# 31          USA         CA  2011-09-16               2       2011-11-02
# 32          USA         NY  2000-01-01               1       2010-03-08
#
#    last_funding_at    status
# 15      2015-03-17  acquired
# 20      2009-05-15  acquired
# 23      2011-02-16  acquired
# 31      2011-11-30  acquired
# 32      2010-03-08  acquired

# %%
DF['category_list'] = DF['category_list'].str.split('|')

# %%
DF.head(2)
# Out:
#             name                          category_list funding_total_usd  \
# 15  1 Mainstream  [Apps, Cable, Distribution, Software]           5000000
# 20  1000 Markets        [Art, E-Commerce, Marketplaces]            500000
#
#    country_code state_code  founded_at  funding_rounds first_funding_at  \
# 15          USA         CA  2012-03-01               1       2015-03-17
# 20          USA         WA  2009-01-01               1       2009-05-15
#
#    last_funding_at    status
# 15      2015-03-17  acquired
# 20      2009-05-15  acquired

# %%
data1.head(2)
# Out:
#         name category_list  funding_total_usd state_code founded_at  \
# 1  TriCipher    Enterprise           40100000         CA   1/1/2000
# 2      Plixi           Web            2600000         CA  3/18/2009
#
#    funding_rounds first_funding_at last_funding_at    status country_code
# 1               4        2/14/2005      12/28/2009  acquired          USA
# 2               1        3/30/2010       3/30/2010  acquired          USA

# %%
data1['category_list'] = data1['category_list'].str.split('|')

# %%
data1.head(2)
# Out:
#         name category_list  funding_total_usd state_code founded_at  \
# 1  TriCipher  [Enterprise]           40100000         CA   1/1/2000
# 2      Plixi         [Web]            2600000         CA  3/18/2009
#
#    funding_rounds first_funding_at last_funding_at    status country_code
# 1               4        2/14/2005      12/28/2009  acquired          USA
# 2               1        3/30/2010       3/30/2010  acquired          USA

# %%
df_combined_v2 = pd.concat([DF, data1], ignore_index=True)

# %%
df_combined_v2.head()
# Out:
#            name                          category_list funding_total_usd  \
# 0  1 Mainstream  [Apps, Cable, Distribution, Software]           5000000
# 1  1000 Markets        [Art, E-Commerce, Marketplaces]            500000
# 2  1000memories                          [Curated Web]           2535000
# 3       100Plus                            [Analytics]           1250000
# 4      1010data                             [Software]          35000000
#
#   country_code state_code  founded_at  funding_rounds first_funding_at  \
# 0          USA         CA  2012-03-01               1       2015-03-17
# 1          USA         WA  2009-01-01               1       2009-05-15
# 2          USA         CA  2010-07-01               2       2010-01-01
# 3          USA         CA  2011-09-16               2       2011-11-02
# 4          USA         NY  2000-01-01               1       2010-03-08
#
#   last_funding_at    status
# 0      2015-03-17  acquired
# 1      2009-05-15  acquired
# 2      2011-02-16  acquired
# 3      2011-11-30  acquired
# 4      2010-03-08  acquired

# %%
df_combined_v2.to_csv('C:\\VS code\\FLEXI\\Projecty\\final_startup_dataset_v2.csv', index=False)

# %%
df_combined_v2.shape
# Out:
# (13959, 10)
